# %%
# %run C:/Users/HSS/dd.py

# %% [markdown]
# ### 회귀 분석의 Condition Number
# - 조건수가 큰 문제: 조건수가 크면 w 계수가 데이터 오차에 민감하게 반응함
#     - 1. 스케일
#     - 2. 다중공선성
#
# - 회귀분석에 앞서 스케일링은 가장 기본

# %% [markdown]
# ### - 범주형 변수를 갖는 회귀분석 문제
# - 범주형 변수가 1개인 경우
#     - [조치1] 범주형 변수값마다 모델을 다르게 만들면 어떨까?
#         - x1이 A,B 값을 갖을 때로 나눈 모델 A와 B는 x2,x3에 대해서 다른 계수[(wa2, wb2), (wa3 ,wb3)]를 갖기 때문에 올바른 모델이 아님
#     - [!조치2] 변수를 더미변수화 한다.
#         - x1에 대한 계수만 (wa1, wb1)으로 나눠지고 나머지 계수는 유지된다. OH~

# %% [markdown]
# ### - 더미변수를 활용한 회귀분석
# - 1. 풀랭크 방식
#     - 상수항을 포함하지 않는 방식, 각 계수는 각 변수에 대응하는 의미를 갖는다.
#     - [그림1] <img src = 'data:image/png;base64,...' width = 50%>
# - 2. 축소랭크 방식
#     - 상수항을 포함한다. 각 계수는 첫번재 변수와의 차이를 나타낸다.
#     - [그림2] <img src = 'data:image/png;base64,...' width = 50%>

# %%
import datetime
from calendar import isleap

# %%
# 윤년: 태양년과 역법을 맞추기 위해 하루 또는 월을 끼우는 해 (4로 나누어 떨어지면 윤, 100으로 나누어 떨어지면 평, 400으로 나누어 떨어지면 윤년)

df_nottem = sm.datasets.get_rdataset("nottem").data

# %%
datetime.timedelta(0.8)
# Out:
# datetime.timedelta(0, 69120)

# %%
60*60*24
# Out:
# 86400
