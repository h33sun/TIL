# %%
import news
# Out:
# C:\Users\HSS\Documents\Anaconda3\envs\tensorflow\lib\importlib\_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# C:\Users\HSS\Documents\Anaconda3\envs\tensorflow\lib\importlib\_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = news.get_news(100, 20200228, 1)

# %% [markdown]
# ### 구글 스프레드 시트에 저장하기
# - ouath 개념
# - ouath 인증 파일 생성
#     - https://console.developers.google.com
#     - 프로젝트 생성
#     - 라이브러리 탭 선택: Google Drive API, Google Sheets API 사용 설정
#     - Oauth 동의 화면
#         - 어플리케이션 이름 설정
#         - google api 범위 추가: drive, spreadsheets
#
#
# - 스프레드 시트에 크롤링한 데이터 저장 및 로드

# %%
df
# Out:
#                                              Title  \
# 0       '세계 3분의1' 65개국서 한국인 입국제한…정부 총력에도 급증세(종합3보)
# 1                           신천지 연관설 구렁텅이에 빠진 미래통합당
# 2           '靑 출신' 정태호·윤영찬 경선 통과…'하명수사 의혹' 송병기는 고배
# 3                  유시민 "미래통합당 심재철의 문대통령 탄핵발언은 자살골"
# 4              민주, 靑출신 윤영찬·정태호 공천…하명수사의혹 송병기는 경선탈락
# 5                         與, 윤영찬·정태호 공천...송병기 공천탈락
# 6              민주당 2차 경선 청와대 인사 모두 본선행…민경욱 현 의원 탈락
# 7                               '마포 5인 회동' 논란, 무엇?
# 8                [나이트포커스] 민주 "비례정당 만들 뜻 없다"...선 긋기
# 9                  TK 230만장 우선 배정에도 "마스크 턱없이 부족해요"
# 10          여 경선서 靑출신 '존재감'…김영배 이어 윤영찬·정태호 승전보(종합)
# 11              윤건영 "비례정당, 꼼수가 원칙 이길까봐 문제의식 얘기한 것"
# 12                   윤영찬·정태호 경선승리…靑 출신 강세 속 송병기 탈락
# 13                 민주당 2차 경선, 윤영찬·정태호 공천…靑 출신 '강세'
# 14              홍준표 “이낙연, 너그러운 척 종로구민 현혹…총선 참패할 것”
# 15          ‘울산시장 선거 개입 의혹’ 송병기 탈락…靑 출신들 민주당 공천 확정
# 16           정경두 국방 “준전시 상황…모든 자원 코로나19 확산 대응에 투입”
# ...
